# %% [markdown]
# <a href="https://colab.research.google.com/github/Vahe0795/Machine-Learning/blob/main/Chess_piece_image_classification_VGG.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import os
from google.colab import drive

drive.mount('/content/drive')
# !ls/content/drive/MyDrive/Chess
os.chdir('/content/drive/MyDrive/Chess')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /bin/bash: ls/content/drive/MyDrive/Chess: No such file or directory

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras import layers, models
import cv2

# %%
from pathlib import Path
data_dir = Path('/content/drive/MyDrive/Chess')
data_dir
# Out:
# PosixPath('/content/drive/MyDrive/Chess')

# %%
image_count = len(list(data_dir.glob('*/*.*')))
print(image_count)
# Out:
# 556

# %%
batch_size = 32

# %%
from tensorflow.keras.utils import image_dataset_from_directory

train_ds = image_dataset_from_directory(
    data_dir,
    validation_split=0.2,
    subset="training",
    seed=42,
    image_size=(224, 224),
    batch_size=batch_size)
# Out:
# Found 552 files belonging to 6 classes.
# Using 442 files for training.

# %%
val_ds = image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="validation",
  seed=42,
  image_size=(224, 224),
  batch_size=batch_size)
# Out:
# Found 552 files belonging to 6 classes.
# Using 110 files for validation.

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['Bishop', 'King', 'Knight', 'Pawn', 'Queen', 'Rook']

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
    for i in range(6):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"));
        plt.title(class_names[labels[i]]);
        plt.axis("off");

# %%
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (32, 224, 224, 3)
# (32,)

# %%
from tensorflow.keras.layers import Rescaling
normalization_layer = Rescaling(1./255)

# %%
AUTOTUNE = tf.data.AUTOTUNE
normalized_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
image_batch, labels_batch = next(iter(normalized_ds))
first_image = image_batch[0]
normalized_ds_1 = val_ds.map(lambda x, y: (normalization_layer(x), y))
image_batch, labels_batch = next(iter(normalized_ds_1))
first_image = image_batch[0]
train_ds = train_ds.cache().prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
from tensorflow.keras.applications.vgg16 import VGG16 
vgg = VGG16(weights='imagenet', include_top=False, input_shape=(224,224,3))
vgg.trainable = False

# %%
def my_model(num_classes = 6):    
    model = tf.keras.Sequential()
    model.add(tf.keras.layers.InputLayer((224, 224, 3)))
    model.add(vgg)
    model.add(tf.keras.layers.Flatten())
    model.add(tf.keras.layers.Dense(128, activation='relu'))
    model.add(tf.keras.layers.BatchNormalization())
    model.add(tf.keras.layers.Dropout(0.5))
    model.add(tf.keras.layers.Dense((num_classes), activation='softmax'))


    tf.keras.backend.clear_session()
    
    model.compile(
    loss=tf.losses.SparseCategoricalCrossentropy(from_logits=True),
    optimizer="adam",
    metrics=["accuracy"]
    )

    return model

model = my_model()

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  flatten (Flatten)           (None, 25088)             0
#
#  dense (Dense)               (None, 128)               3211392
#
#  batch_normalization (BatchN  (None, 128)              512
#  ormalization)
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 6)                 774
#
# =================================================================
# Total params: 17,927,366
# Trainable params: 3,212,422
# Non-trainable params: 14,714,944
# _________________________________________________________________

# %%
epochs = 25
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/25
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   return dispatch_target(*args, **kwargs)
# 14/14 [==============================] - 287s 21s/step - loss: 1.5764 - accuracy: 0.5068 - val_loss: 3.9072 - val_accuracy: 0.6455
# Epoch 2/25
# 14/14 [==============================] - 280s 20s/step - loss: 0.3988 - accuracy: 0.8846 - val_loss: 1.3109 - val_accuracy: 0.7455
# Epoch 3/25
# 14/14 [==============================] - 280s 20s/step - loss: 0.2153 - accuracy: 0.9457 - val_loss: 0.9900 - val_accuracy: 0.7545
# Epoch 4/25
# 14/14 [==============================] - 279s 20s/step - loss: 0.1558 - accuracy: 0.9706 - val_loss: 0.9268 - val_accuracy: 0.7364
# Epoch 5/25
# 14/14 [==============================] - 277s 20s/step - loss: 0.0967 - accuracy: 0.9796 - val_loss: 0.8345 - val_accuracy: 0.7455
# Epoch 6/25
# 14/14 [==============================] - 275s 20s/step - loss: 0.0689 - accuracy: 0.9887 - val_loss: 0.7760 - val_accuracy: 0.7636
# Epoch 7/25
# 14/14 [==============================] - 276s 20s/step - loss: 0.0574 - accuracy: 0.9842 - val_loss: 0.7707 - val_accuracy: 0.7545
# Epoch 8/25
# 14/14 [==============================] - 275s 20s/step - loss: 0.0623 - accuracy: 0.9932 - val_loss: 0.7570 - val_accuracy: 0.7727
# Epoch 9/25
# 14/14 [==============================] - 275s 20s/step - loss: 0.0464 - accuracy: 0.9910 - val_loss: 0.7399 - val_accuracy: 0.7636
# Epoch 10/25
# 14/14 [==============================] - 274s 20s/step - loss: 0.0421 - accuracy: 0.9932 - val_loss: 0.7016 - val_accuracy: 0.7727
# Epoch 11/25
# 14/14 [==============================] - 274s 20s/step - loss: 0.0320 - accuracy: 1.0000 - val_loss: 0.7213 - val_accuracy: 0.7545
# Epoch 12/25
# 14/14 [==============================] - 274s 20s/step - loss: 0.0378 - accuracy: 0.9887 - val_loss: 0.7371 - val_accuracy: 0.7545
# Epoch 13/25
# 14/14 [==============================] - 275s 20s/step - loss: 0.0212 - accuracy: 1.0000 - val_loss: 0.7476 - val_accuracy: 0.7455
# Epoch 14/25
# 14/14 [==============================] - 275s 20s/step - loss: 0.0259 - accuracy: 0.9977 - val_loss: 0.7369 - val_accuracy: 0.7636
# Epoch 15/25
# 14/14 [==============================] - 274s 20s/step - loss: 0.0190 - accuracy: 1.0000 - val_loss: 0.7293 - val_accuracy: 0.7545
# Epoch 16/25
# 14/14 [==============================] - 275s 20s/step - loss: 0.0162 - accuracy: 1.0000 - val_loss: 0.7412 - val_accuracy: 0.7636
# Epoch 17/25
# 14/14 [==============================] - 274s 20s/step - loss: 0.0157 - accuracy: 0.9977 - val_loss: 0.7410 - val_accuracy: 0.7636
# Epoch 18/25
# 14/14 [==============================] - 276s 20s/step - loss: 0.0203 - accuracy: 0.9977 - val_loss: 0.7659 - val_accuracy: 0.7545
# Epoch 19/25
# 14/14 [==============================] - 275s 20s/step - loss: 0.0221 - accuracy: 0.9977 - val_loss: 0.7373 - val_accuracy: 0.7545
# Epoch 20/25
# 14/14 [==============================] - 275s 20s/step - loss: 0.0103 - accuracy: 1.0000 - val_loss: 0.7268 - val_accuracy: 0.7545
# Epoch 21/25
# 14/14 [==============================] - 274s 20s/step - loss: 0.0083 - accuracy: 1.0000 - val_loss: 0.7268 - val_accuracy: 0.7727
# Epoch 22/25
# 14/14 [==============================] - 275s 20s/step - loss: 0.0129 - accuracy: 0.9977 - val_loss: 0.7675 - val_accuracy: 0.7818
# Epoch 23/25
# 14/14 [==============================] - 274s 20s/step - loss: 0.0088 - accuracy: 1.0000 - val_loss: 0.7890 - val_accuracy: 0.7636
# Epoch 24/25
# 14/14 [==============================] - 274s 20s/step - loss: 0.0089 - accuracy: 1.0000 - val_loss: 0.7875 - val_accuracy: 0.7727
# Epoch 25/25
# 14/14 [==============================] - 273s 20s/step - loss: 0.0062 - accuracy: 1.0000 - val_loss: 0.7882 - val_accuracy: 0.7727

# %%
epochs_range = [i+1 for i in range(epochs)]
plt.plot(epochs_range, model.history.history['accuracy'], '-o', label='Train')
plt.plot(epochs_range, model.history.history['val_accuracy'], '-x',label='Validation')

plt.ylabel('Accuracy')
plt.xlabel('Epochs')

plt.legend();

# %%
label = np.array([])
for prediction, labels in val_ds:
  label = np.concatenate([label, labels.numpy()])
label
# Out:
# array([5., 4., 0., 2., 0., 1., 0., 4., 2., 5., 2., 0., 3., 4., 5., 3., 3.,
#        0., 0., 5., 0., 1., 0., 5., 5., 5., 0., 5., 3., 0., 2., 0., 3., 0.,
#        2., 5., 1., 1., 5., 2., 2., 4., 4., 3., 1., 4., 1., 3., 2., 3., 0.,
#        5., 1., 5., 2., 2., 5., 1., 3., 2., 3., 1., 5., 3., 3., 0., 3., 1.,
#        5., 3., 2., 4., 2., 4., 5., 2., 4., 5., 5., 2., 1., 5., 2., 3., 2.,
#        5., 1., 3., 0., 1., 5., 5., 5., 4., 3., 5., 4., 4., 3., 5., 0., 3.,
#        3., 3., 3., 2., 3., 2., 4., 2.])

# %%
Y_pred = model.predict(val_ds, 110 // batch_size+1)
y_pred = np.argmax(Y_pred, axis=1)

# %%
from sklearn.metrics import confusion_matrix

matrix1 = confusion_matrix(label, y_pred)

# %%
import seaborn as sns

sns.heatmap(matrix1, annot=True, cmap='Blues', yticklabels=class_names, xticklabels=class_names);

# %%
from sklearn.metrics import accuracy_score
score = accuracy_score(label, y_pred)
score
# Out:
# 0.7727272727272727
